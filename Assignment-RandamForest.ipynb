# %% [raw]
# Objective:
# Use the Glass dataset and apply the Random forest model.

# %% [markdown]
# ### 1. Data Preparation:

# %%
import pandas as pd
df=pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# ### 2. Exploratory Data Analysis (EDA):

# %%
df.shape, df.columns
# Out:
# ((214, 10),
#  Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object'))

# %%
df.nunique()
# Out:
# RI      178
# Na      142
# Mg       94
# Al      118
# Si      133
# K        65
# Ca      143
# Ba       34
# Fe       32
# Type      6
# dtype: int64

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
# Check for Numeric columns and Categorical columns
num_col = df.select_dtypes(include=['number']).columns
cat_col=df.select_dtypes(include=['object']).columns
print("Numeric columns are: ", num_col)
print("Categorical columns are: ", cat_col)
# Out:
# Numeric columns are:  Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')
# Categorical columns are:  Index([], dtype='object')

# %% [markdown]
# #### There are no Categorical columns in the dataset

# %%
# Handle missing values appropriately (e.g., imputation, deletion).
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
# Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).
df_new=df.corr(numeric_only = True)
df_new
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
# fillna function in python (in pandas library) fills missing values in data frame
# replces missing valuse in a column or columns with a specified value
df_new = df.fillna(" ")
df_new
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df_new.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Histograms
for i in df_new.select_dtypes(include=['number']).columns:
  plt.figure(figsize=(10,5))
  sns.histplot(df_new[i], bins =30, kde=True)
  plt.title(f"Distribution of {i}")
  plt.show()

# %%
# Identify the numerical data
z=df.corr(numeric_only=True)
z
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %% [markdown]
# ### 2: Data Visualization:

# %%
for i in num_col:
  plt.figure(figsize=(10,5))
  sns.boxplot(z[i])
  plt.title(f'Boxplot of {i}')
  plt.show()

# %%
# plot heatmap
import seaborn as sns
sns.heatmap(z,annot=True)
plt.show()

# %%
# plot pair plot
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### Random Forest Model Implementation

# %%
df.shape, df.columns
# Out:
# ((214, 10),
#  Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object'))

# %%
x = df.drop('Type', axis=1)# Fetaures
y = df['Type']# target

# %%
# Now split the data into training and validation sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)  # 80% train, 20% validation

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True)
from sklearn.metrics import (accuracy_score, classification_report)

classifier_rf = classifier_rf.fit(x_train, y_train)

# predict using classifier
y_pred = classifier_rf.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.65      1.00      0.79        11
#            2       0.73      0.57      0.64        14
#            3       1.00      0.33      0.50         3
#            5       1.00      0.50      0.67         4
#            6       1.00      1.00      1.00         3
#            7       0.89      1.00      0.94         8
#
#     accuracy                           0.77        43
#    macro avg       0.88      0.73      0.76        43
# weighted avg       0.80      0.77      0.75        43

# %%
# checking the oob score
classifier_rf.oob_score_
# Out:
# 0.7017543859649122

# %% [markdown]
# ### Bagging and Boosting Methods

# %%
# define a decision tree classifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

results = cross_val_score(DecisionTreeClassifier(),x,y,cv=5)
results

#mean accuracy score
results.mean()
# Out:
# 0.593687707641196

# %%
# Define a bagging classifier
from sklearn.ensemble import BaggingClassifier

model = BaggingClassifier(DecisionTreeClassifier(),n_estimators = 100,
                          max_samples=0.8,oob_score=True,random_state=0)
model.fit(x_train, y_train)

#accuracy score--->training set
model.oob_score_
# Out:
# 0.7076023391812866

# %%
#accuracy score --> testing set
model.score(x_test,y_test)

# to use cross_val_score method
model = BaggingClassifier(DecisionTreeClassifier(),n_estimators = 100,
                          max_samples=0.8,oob_score=True,random_state=0)
results = cross_val_score(model,x,y,cv=5)
results.mean()
# Out:
# 0.6637873754152824

# %%
# define a random forest classifier...
from sklearn.ensemble import RandomForestClassifier
results = cross_val_score(RandomForestClassifier(),x,y,cv=5)
results.mean()
# Out:
# 0.6826135105204874

# %% [markdown]
# ### Additional Notes:

# %% [raw]
# 1. Explain Bagging and Boosting methods. How is it different from each other.
# ANS:
# Bagging: It is a homogeneous weak learners’ model that learns from each other independently in parallel and combines them for determining the model average. Bootstrap Aggregating, also known as bagging, is a machine learning ensemble meta-algorithm designed to improve the stability and accuracy of machine learning algorithms used in statistical classification and regression. It decreases the variance and helps to avoid overfitting. It is usually applied to decision tree methods. Bagging is a special case of the model averaging approach. Boosting is an ensemble modeling technique designed to create a strong classifier by combining multiple weak classifiers. The process involves building models sequentially, where each new model aims to correct the errors made by the previous ones.
#
#
# Boosting: It is also a homogeneous weak learners’ model but works differently from Bagging. In this model, learners learn sequentially and adaptively to improve model predictions of a learning algorithm.Boosting is an ensemble modeling technique designed to create a strong classifier by combining multiple weak classifiers. The process involves building models sequentially, where each new model aims to correct the errors made by the previous ones.
#
# These two are different as below:
# Bagging:
# 1. The simplest way of combining predictions that belong to the same type.
# 2. Aim to decrease variance, not bias.
# 3. Each model receives equal weight.
# 4. Each model is built independently.
# 5. Different training data subsets are selected using row sampling with replacement and random sampling methods from the entire training dataset.
# 6. Bagging tries to solve the over-fitting problem.
# 7. If the classifier is unstable (high variance), then apply bagging.
# 8. In this base classifiers are trained parallelly.
# Boosting:
# 1. A way of combining predictions that belong to the different types.
# 2. Aim to decrease bias, not variance.
# 3. Models are weighted according to their performance.
# 4. New models are influenced by the performance of previously built models.
# 5. Iteratively train models, with each new model focusing on correcting the errors (misclassifications or high residuals) of the previous models
# 6. Boosting tries to reduce bias.
# 7. If the classifier is stable and simple (high bias) the apply boosting.
# 8. In this base classifiers are trained sequentially.

# %% [raw]
# 2. Explain how to handle imbalance in the data.
# ANS:
# Bagging:
# Bagging methods like Random Forest address class imbalance by creating multiple
# decision trees on different bootstrap samples of the data.  While bootstrapping
# itself doesn't directly correct the imbalance, the aggregation of predictions
# from these diverse trees can make the model less sensitive to the skewed class
# distribution.  Crucially, algorithms like Random Forest often have parameters that
# allow for weighting of classes (class_weight parameter in scikit-learn) in the
# tree-building process itself.  This explicitly addresses the imbalance by
# penalizing misclassification of the minority class more heavily.
#
#
# Boosting:
# Boosting algorithms like AdaBoost, Gradient Boosting, and XGBoost handle
# imbalance differently.  They sequentially build weak learners (typically decision trees),
# giving more weight to the misclassified instances in each iteration.  This focuses
# the model's learning on the harder-to-classify examples, including those from the
# minority class.  Boosting algorithms generally have built-in parameters for class
# weighting, allowing you to directly influence how much each misclassification contributes
# to the subsequent model updates.
