# %%
# Load the dataset into a data analysis tool or programming environment 
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\DataScience\Assignments\01 Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
# Print Column names
print("Columns in CSV file: ", df.columns)

# Check if All Columns are Numeric
numeric_columns = df.select_dtypes(include=np.number).columns
print("Numeric columns are: ", numeric_columns)
# Out:
# Columns in CSV file:  Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')
# Numeric columns are:  Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Calculate the mean, median, mode, and standard deviation for these columns.
import statistics as st

# For Volume: Calculate medin, mean, Variance and standard devation 
mean_Valume =st.mean(df.Volume)
median_Valume =st.median(df.Volume)
mode_Valume =st.multimode(df.Volume)
variance_Valume =st.variance(df.Volume)
stdev_Valume =st.stdev(df.Volume)
print("Valume: ")
print("mean    ", mean_Valume)
print("median  ", median_Valume)
print("mode    ", mode_Valume)
print("variance", variance_Valume)
print("stdev:  ", stdev_Valume)

# brief interpretation of these statistics:

# mean: Avarage value of this column is 5.05
# median: Middle value this column is 4.0 after arranging in oder
# mode: Only one value i.e 10 is repative (frequently occurring) in this column
# variance: 17.9 i.e average of "squared deviation scores" where "squared deviation scores" is observation - true mean
# standard deviation: 4.23 i.e square root of variance
# Out:
# Valume:
# mean     5.066666666666666
# median   4.0
# mode     [3]
# variance 17.906458797327396
# stdev:   4.231602391213923

# %%
# For Avg Price: Calculate medin, mean, Variance and standard devation 
mean_AvgPrice =st.mean(getattr(df, 'Avg Price'))
median_AvgPrice =st.median(getattr(df, 'Avg Price'))
mode_AvgPrice =st.multimode(getattr(df, 'Avg Price'))
variance_AvgPrice =st.variance(getattr(df, 'Avg Price'))
stdev_AvgPrice =st.stdev(getattr(df, 'Avg Price'))
print("Avg Price: ")
print("mean    ", mean_AvgPrice)
print("median  ", median_AvgPrice)
print("mode    ", mode_AvgPrice)
print("variance", variance_AvgPrice)
print("stdev:  ", stdev_AvgPrice)
# Out:
# Avg Price:
# mean     10453.433333333332
# median   1450.0
# mode     [8100, 400, 450, 500, 1300]
# variance 326882959.02115816
# stdev:   18079.90483993647

# %%
# For Total Sales Value: Calculate medin, mean, Variance and standard devation 
mean_TotalSalesValue =st.mean(getattr(df, 'Total Sales Value'))
median_TotalSalesValue =st.median(getattr(df, 'Total Sales Value'))
mode_TotalSalesValue =st.multimode(getattr(df, 'Total Sales Value'))
variance_TotalSalesValue =st.variance(getattr(df, 'Total Sales Value'))
stdev_TotalSalesValue =st.stdev(getattr(df, 'Total Sales Value'))
print("Total Sales Value: ")
print("mean    ", mean_TotalSalesValue)
print("median  ", median_TotalSalesValue)
print("mode    ", mode_TotalSalesValue)
print("variance", variance_TotalSalesValue)
print("stdev:  ", stdev_TotalSalesValue)
# Out:
# Total Sales Value:
# mean     33812.83555555555
# median   5700.0
# mode     [24300]
# variance 2553793721.625459
# stdev:   50535.07417255326

# %%
# For Discount Rate (%): Calculate medin, mean, Variance and standard devation 
mean_DiscountRate =st.mean(getattr(df, 'Discount Rate (%)'))
median_DiscountRate =st.median(getattr(df, 'Discount Rate (%)'))
mode_DiscountRate =st.mode(getattr(df, 'Discount Rate (%)'))# No common data in this column
variance_DiscountRate =st.variance(getattr(df, 'Discount Rate (%)'))
stdev_DiscountRate =st.stdev(getattr(df, 'Discount Rate (%)'))
print("Discount Rate (%): ")
print("mean    ", mean_DiscountRate)
print("median  ", median_DiscountRate)
print("mode    ", mode_DiscountRate)
print("variance", variance_DiscountRate)
print("stdev:  ", stdev_DiscountRate)
# Out:
# Discount Rate (%):
# mean     15.155241895330914
# median   16.57776564929597
# mode     11.654820286277229
# variance 17.813482536655926
# stdev:   4.220602153325509

# %%
# For Discount Amount: Calculate medin, mean, Variance and standard devation 
mean_DiscountAmount =st.mean(getattr(df, 'Discount Amount'))
median_DiscountAmount =st.median(getattr(df, 'Discount Amount'))
mode_DiscountAmount =st.mode(getattr(df, 'Discount Amount'))# No common data in this column
variance_DiscountAmount =st.variance(getattr(df, 'Discount Amount'))
stdev_DiscountAmount =st.stdev(getattr(df, 'Discount Amount'))
print("Discount Amount: ")
print("mean    ", mean_DiscountAmount)
print("median  ", median_DiscountAmount)
print("mode    ", mode_DiscountAmount)
print("variance", variance_DiscountAmount)
print("stdev:  ", stdev_DiscountAmount)
# Out:
# Discount Amount:
# mean     3346.499424342415
# median   988.9337332382784
# mode     21153.49881959317
# variance 20339224.738869175
# stdev:   4509.9029633539985

# %%
# For Net Sales Value: Calculate medin, mean, Variance and standard devation 
mean_NetSalesValue =st.mean(getattr(df, 'Net Sales Value'))
median_NetSalesValue =st.median(getattr(df, 'Net Sales Value'))
mode_NetSalesValue =st.mode(getattr(df, 'Net Sales Value'))# No common data in this column
variance_NetSalesValue =st.variance(getattr(df, 'Net Sales Value'))
stdev_NetSalesValue =st.stdev(getattr(df, 'Net Sales Value'))
print("Net Sales Value: ")
print("mean    ", mean_NetSalesValue)
print("median  ", median_NetSalesValue)
print("mode    ", mode_NetSalesValue)
print("variance", variance_NetSalesValue)
print("stdev:  ", stdev_NetSalesValue)
# Out:
# Net Sales Value:
# mean     30466.336131270138
# median   4677.788059301853
# mode     160346.50118040683
# variance 2149125043.9881463
# stdev:   46358.65662406695

# %%
# Plotting hystograms for numerical columns

# %%
# Check if All Columns are Numeric
numeric_columns = df.select_dtypes(include=np.number).columns
print("Numeric columns are: ", numeric_columns)
# Out:
# Numeric columns are:  Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Rename the columns to one single word
df = df.rename(columns={'Avg Price': 'AvgPrice','Total Sales Value': 'TotalSalesValue','Discount Rate (%)':'DiscountRate','Discount Amount':'DiscountAmount','Net Sales Value':'NetSalesValue'})

# Check for Numeric columns
numeric_columns1 = df.select_dtypes(include=np.number).columns
print("Numeric columns are: ", numeric_columns1)
# Out:
# Numeric columns are:  Index(['Volume', 'AvgPrice', 'TotalSalesValue', 'DiscountRate',
#        'DiscountAmount', 'NetSalesValue'],
#       dtype='object')

# %%
# Plotting a basic histogram for column Volume
#plt.hist(df.Volume, bins=30, color='skyblue', edgecolor='black')

# Creating a customized histogram with a density plot
sns.histplot(df.Volume, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.title('Histogram for Volume v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Plotting hystogram plots for numeric columns

# %%
# Creating a customized histogram with a density plot
sns.histplot(df.AvgPrice, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Average Price')
plt.ylabel('Frequency')
plt.title('Histogram for Average Price v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Creating a customized histogram with a density plot
sns.histplot(df.TotalSalesValue, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
plt.title('Histogram for Total Sales Value v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Creating a customized histogram with a density plot
sns.histplot(df.DiscountRate, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Discount Rate')
plt.ylabel('Frequency')
plt.title('Histogram for Total Discount Rate v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Creating a customized histogram with a density plot
sns.histplot(df.DiscountAmount, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
plt.title('Histogram for Total Discount Amount v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Creating a customized histogram with a density plot
sns.histplot(df.NetSalesValue, bins=30, kde=True, color='lightgreen', edgecolor='red')

# Adding labels and title
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')
plt.title('Histogram for Net Sales Value v/s Frequency')
 
# Display the plot
plt.show()

# %%
# Plotting box plots for numeric columns
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\DataScience\Assignments\01 Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Adding labels and title
plt.xlabel('Volume')
plt.ylabel('Business Unit')
plt.title('Box plot of Volume v/s Business Unit ')
sns.boxplot(x="Volume", y="BU",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# Mobles and Lifstyle Business units have less outliers where as FMCG having more outliers

# %%
# Adding labels and title
plt.xlabel('Average Price ')
plt.ylabel('Brand')
plt.title('Box plot of Average Price v/s Brand ')
sns.boxplot(x="Avg Price", y="Brand",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# Only Gear is having some outliers, all are within specified range

# %%
# Adding labels and title
plt.xlabel('Total Sales Value ')
plt.ylabel('Brand')
plt.title('Box plot of Total Sales Value v/s Model ')
sns.boxplot(x="Total Sales Value", y="Model",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# S-20 and RU-9 Plus having more outliers

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Adding labels and title
plt.xlabel('Discount Rate (%) ')
plt.ylabel('SKU')
plt.title('Box plot of Discount Rate (%) v/s SKU ')
sns.boxplot(x="Discount Rate (%)", y="SKU",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# No outliers

# %%
# Adding labels and title
plt.xlabel('Discount Amount ')
plt.ylabel('Day')
plt.title('Box plot of Discount Amount v/s Day ')
sns.boxplot(x="Discount Amount", y="Day",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# Thursday and Friday have mode outliers

# %%
# Adding labels and title
plt.xlabel('Net Sales Value ')
plt.ylabel('Business Unit')
plt.title('Box plot of Net Sales Value v/s Business Unit ')
sns.boxplot(x="Net Sales Value", y="BU",color='lightblue', data=df) 

# Display the plot
plt.show()

# Analysis:
# no outliers for Mobiles unit where as FMCG and Lifstyle have small outliers

# %%
# Bar Chart Analysis for Categorical Column:

# %%
# Check for Numeric columns
numeric_columns1 = df.select_dtypes(include=np.number).columns
print("Numeric columns are: ", numeric_columns1)
df.columns
# Out:
# Numeric columns are:  Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# calegoric columns are 
# Date, Day, SKU, City, BU, Brand, Model

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Bar chart for Volume and Date")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.bar(df.Date,df.Volume)
plt.show()

# %%
plt.title("Bar chart for Volume and SKU")
plt.xlabel("SKu")
plt.ylabel("Volume")
plt.bar(df.SKU,df.Volume)
plt.show()

# %%
plt.title("Bar chart for Volume and City")
plt.xlabel("City")
plt.ylabel("Volume")
plt.bar(df.City,df.Volume)
plt.show()

# %%
plt.title("Bar chart for Volume and BU")
plt.xlabel("BU")
plt.ylabel("Volume")
plt.bar(df.BU,df.Volume)
plt.show()

# %%
plt.title("Bar chart for Volume and Brand")
plt.xlabel("Brand")
plt.ylabel("Volume")
plt.bar(df.Brand,df.Volume)
plt.show()

# %%
plt.title("Bar chart for Volume and Model")
plt.xlabel("Model")
plt.ylabel("Volume")
plt.bar(df.Model,df.Volume)
plt.show()

# %%
# Standardization of Numerical Variables

# %%
# Step 1:
# Load the dataset into a data analysis tool or programming environment 
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\DataScience\Assignments\01 Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Step 2: Calculate the Mean
# Calculate the mean, median, mode, and standard deviation for these columns.
import statistics as st

# For Volume: Calculate mean and standard devation 
mean_Valume =st.mean(df.Volume)
stdev_Valume =st.stdev(df.Volume)

# Perform Z-score normalization
z_scores_Volume = (df.Volume - mean_Valume) / stdev_Valume

# Print the results
print("Original data:", df.Volume)
print("Mean:", mean_Valume)
print("Standard Deviation:", stdev_Valume)
print("Z-scores:", z_scores_Volume)
# Out:
# Original data: 0      15
# 1      10
# 2       7
# 3       6
# 4       3
#        ..
# 445     2
# 446     6
# 447     2
# 448     3
# 449     1
# Name: Volume, Length: 450, dtype: int64
# Mean: 5.066666666666666
# Standard Deviation: 4.231602391213923
# Z-scores: 0      2.347417
# 1      1.165831
# 2      0.456880
# 3      0.220563
# 4     -0.488389
#          ...
# 445   -0.724706
# 446    0.220563
# 447   -0.724706
# 448   -0.488389
# 449   -0.961023
# Name: Volume, Length: 450, dtype: float64

# %%
#Step 3 : Outlier detection
# Outlier detection: Z-scores beyond ±3 are considered outliers
outliers = np.where(np.abs(z_scores_Volume) > 3)
print (outliers)
#plt.plot(outliers[0], df.Volume[outliers], 'ro', label='Outliers')
plt.figure(figsize=(20, 8))
plt.plot(df.Volume, 'bo-', label='Original Data')
#plt.plot(outliers[0], df.Volume[outliers], 'ro', label='Outliers')
plt.axhline(mean_Valume, color='g', linestyle='--', label='Mean')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Data with Outliers Detected')
plt.legend()
plt.show()
# Out:
# (array([ 40,  70, 100, 190, 250, 280, 310, 400], dtype=int64),)

# %%
# Conversion of Categorical Data into Dummy Variables

# The get_dummies() function from the Pandas library in Python 
# is a powerful tool for converting categorical variable(s) into 
# dummy or indicator variables. It is extensively utilized in 
# data preprocessing, especially before feeding the data into a 
# machine learning model. This function creates a new DataFrame 
# with binary values (0s and 1s), representing the presence of 
# each categorical value, making it easier for models to process 
# categorical data without ambiguity.

# %%
# Convert categorical columns to dummy variables
dummies = pd.get_dummies(df)
print(dummies)
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
# ...

# %%
# Conclusion
# With this exercise, we will be able to find out ,ean, Medean, st.dev
# plot the hys, box and bar plots to ideintiy the outliers which gives the 
# correct data set for ML model.
